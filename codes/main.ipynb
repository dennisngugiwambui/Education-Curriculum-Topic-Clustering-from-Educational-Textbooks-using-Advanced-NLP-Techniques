# %% [markdown]
# # MASTERS RESEARCH: NLP-Based Curriculum Topic Clustering
#
# **Research Title:** Automated Curriculum Topic Clustering from Educational Textbooks using Advanced NLP Techniques
#
# **Author:** Dennis Ngugi
# **Research Level:** Masters Thesis
# **Focus:** Educational Data Mining, Topic Modeling, Hierarchical Clustering
#
# ## Abstract Implementation
#
# This notebook implements a comprehensive NLP-based system for curriculum topic clustering from educational textbooks, focusing on the application of topic modeling and hierarchical clustering techniques. The system processes large collections of textbook content, automatically generates curriculum maps, and provides educators with tools for designing coherent lesson plans while detecting content overlaps.
#
# **Key Technologies:**
# - Latent Dirichlet Allocation (LDA)
# - Hierarchical Agglomerative Clustering
# - Advanced Natural Language Processing
# - Educational Data Mining
# - Automated Content Analysis

# %%
# PHASE 0: ENVIRONMENT SETUP AND REQUIREMENTS INSTALLATION
import subprocess
import sys
import os
from datetime import datetime

print("🎓 MASTERS RESEARCH: NLP-BASED CURRICULUM TOPIC CLUSTERING")
print("=" * 70)
print(f"Execution Started: {datetime.now()}")
print("=" * 70)

# Install requirements
requirements = [
    'pandas>=2.0.3', 'numpy>=1.24.3', 'scikit-learn>=1.3.0',
    'nltk>=3.8.1', 'matplotlib>=3.7.2', 'seaborn>=0.12.2',
    'requests>=2.31.0', 'beautifulsoup4>=4.12.2', 'selenium>=4.15.2',
    'wordcloud>=1.9.2', 'plotly>=5.15.0', 'gensim>=4.3.0',
    'pyLDAvis>=3.4.0', 'networkx>=3.1', 'webdriver-manager>=4.0.1'
]

print("📦 Installing research-grade packages...")
for package in requirements:
    try:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', package, '--quiet'])
        print(f"✅ {package.split('>=')[0]}")
    except Exception as e:
        print(f"⚠️ Failed: {package} - {e}")

print("\n✅ Environment setup completed!")
# Out:
# 🎓 MASTERS RESEARCH: NLP-BASED CURRICULUM TOPIC CLUSTERING
# ======================================================================
# Execution Started: 2025-09-08 08:47:28.130470
# ======================================================================
# 📦 Installing research-grade packages...
# ✅ pandas
# ✅ numpy
# ✅ scikit-learn
# ✅ nltk
# ✅ matplotlib
# ✅ seaborn
# ✅ requests
# ✅ beautifulsoup4
# ✅ selenium
# ✅ wordcloud
# ✅ plotly
# ✅ gensim
# ✅ pyLDAvis
# ✅ networkx
# ✅ webdriver-manager
#
# ✅ Environment setup completed!

# %%
# PHASE 1: COMPREHENSIVE DATA COLLECTION
print("\n🔍 PHASE 1: COMPREHENSIVE DATA COLLECTION")
print("=" * 50)

# Execute main research pipeline
with open('main.py', 'r', encoding='utf-8') as f:
    exec(f.read())
# Out:
# 🔍 PHASE 1: COMPREHENSIVE DATA COLLECTION
# ==================================================
# 🎓 MASTERS RESEARCH: NLP-BASED CURRICULUM TOPIC CLUSTERING
# ================================================================================
# Automated curriculum mapping using advanced NLP techniques
# Author: Dennis Ngugi | Masters Research Project
# ================================================================================
# 2025-09-08 08:48:17,776 | INFO     | Logging initialized: logs\masters_research_execution_20250908_084817.log
# 2025-09-08 08:48:17,780 | INFO     | 🎓 MASTERS RESEARCH PIPELINE INITIALIZED
# 2025-09-08 08:48:17,780 | INFO     | Research Title: NLP-Based Curriculum Topic Clustering from Educational Textbooks
# 2025-09-08 08:48:17,780 | INFO     | Configuration: {'research_title': 'NLP-Based Curriculum Topic Clustering from Educational Textbooks', 'n_topics_lda': 30, 'n_clusters_hierarchical': 25, 'max_scraping_workers': 3, 'scraping_delay': 1.5, 'min_content_length': 100, 'topic_coherence_threshold': 0.4, 'cluster_silhouette_threshold': 0.3}
# 2025-09-08 08:48:17,793 | INFO     | 🎓 STARTING MASTERS RESEARCH PIPELINE
# 2025-09-08 08:48:17,793 | INFO     | ================================================================================
# 2025-09-08 08:48:17,793 | INFO     | Research Title: NLP-Based Curriculum Topic Clustering from Educational Textbooks
# 2025-09-08 08:48:17,793 | INFO     | ================================================================================
# 2025-09-08 08:48:17,793 | INFO     | 🔧 Phase 0: Requirements Installation
# 2025-09-08 08:48:17,799 | INFO     | Installing required packages for masters research...
# 2025-09-08 08:49:42,343 | INFO     | ✅ Requirements installation completed successfully
# 2025-09-08 08:49:42,343 | INFO     | 🔍 Validating research environment...
# 2025-09-08 08:49:45,785 | INFO     | 📥 Downloading required NLTK data...
# 2025-09-08 08:49:48,208 | INFO     | ✅ Environment validation successful
# 2025-09-08 08:49:48,209 | INFO     | 🔍 Phase 1: Comprehensive Data Collection
# 2025-09-08 08:49:48,517 | INFO     | Discovering all educational content URLs...
# 2025-09-08 08:49:48,517 | INFO     | 🔍 Discovering all educational content URLs...
# 2025-09-08 08:49:48,519 | INFO     | ====== WebDriver manager ======
# 2025-09-08 08:49:50,639 | INFO     | Get LATEST chromedriver version for google-chrome
# 2025-09-08 08:49:51,105 | INFO     | Get LATEST chromedriver version for google-chrome
# 2025-09-08 08:49:51,429 | INFO     | Driver [C:\Users\Denno\.wdm\drivers\chromedriver\win64\139.0.7258.154\chromedriver-win32/chromedriver.exe] found in cache
# 2025-09-08 08:49:54,143 | INFO     | Exploring https://kec.ac.ke/ for additional URLs...
# 2025-09-08 08:50:00,984 | INFO     | Exploring https://lms.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:50:06,968 | INFO     | Exploring https://elimika.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:50:15,839 | INFO     | Exploring https://oer.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:50:50,629 | INFO     | Exploring https://resources.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:50:50,971 | WARNING  | Error exploring https://resources.kec.ac.ke/: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.155)
# Stacktrace:
# 	GetHandleVerifier [0x0xf6a8a3+63283]
# 	GetHandleVerifier [0x0xf6a8e4+63348]
# 	(No symbol) [0x0xda3e43]
# 	(No symbol) [0x0xda156b]
# 	(No symbol) [0x0xd94d32]
# 	(No symbol) [0x0xd96768]
# 	(No symbol) [0x0xd94fc8]
# 	(No symbol) [0x0xd94b03]
# 	(No symbol) [0x0xd94811]
# 	(No symbol) [0x0xd927b4]
# 	(No symbol) [0x0xd9315b]
# 	(No symbol) [0x0xda785e]
# 	(No symbol) [0x0xe332e7]
# 	(No symbol) [0x0xe1141c]
# 	(No symbol) [0x0xe3271a]
# 	(No symbol) [0x0xe11216]
# 	(No symbol) [0x0xde0855]
# 	(No symbol) [0x0xde16f4]
# 	GetHandleVerifier [0x0x11dbb43+2623955]
# 	GetHandleVerifier [0x0x11d6daa+2604090]
# 	GetHandleVerifier [0x0xf9069a+218410]
# 	GetHandleVerifier [0x0xf80ed8+154984]
# 	GetHandleVerifier [0x0xf8742d+180925]
# 	GetHandleVerifier [0x0xf722b8+94536]
# 	GetHandleVerifier [0x0xf72442+94930]
# 	GetHandleVerifier [0x0xf5d5ea+9338]
# 	BaseThreadInitThunk [0x0x75f05d49+25]
# 	RtlInitializeExceptionChain [0x0x7792d2fb+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x7792d281+561]
#
# 2025-09-08 08:50:50,971 | INFO     | Exploring https://orangebook.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:51:02,198 | INFO     | ✅ Discovered 100 URLs to scrape
# 2025-09-08 08:51:02,199 | INFO     | 📋 Discovered 100 URLs for comprehensive scraping
# 2025-09-08 08:51:02,201 | INFO     | Executing comprehensive content scraping...
# 2025-09-08 08:51:02,204 | INFO     | 🚀 Starting comprehensive content scraping...
# 2025-09-08 08:51:02,206 | INFO     | 🔍 Discovering all educational content URLs...
# 2025-09-08 08:51:02,210 | INFO     | ====== WebDriver manager ======
# 2025-09-08 08:51:03,756 | INFO     | Get LATEST chromedriver version for google-chrome
# 2025-09-08 08:51:04,091 | INFO     | Get LATEST chromedriver version for google-chrome
# 2025-09-08 08:51:04,424 | INFO     | Driver [C:\Users\Denno\.wdm\drivers\chromedriver\win64\139.0.7258.154\chromedriver-win32/chromedriver.exe] found in cache
# 2025-09-08 08:51:05,970 | INFO     | Exploring https://kec.ac.ke/ for additional URLs...
# 2025-09-08 08:51:12,981 | INFO     | Exploring https://lms.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:51:18,879 | INFO     | Exploring https://elimika.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:51:27,638 | INFO     | Exploring https://oer.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:51:53,112 | INFO     | Exploring https://resources.kec.ac.ke/ for additional URLs...
# 2025-09-08 08:51:53,476 | WARNING  | Error exploring https://resources.kec.ac.ke/: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=139.0.7258.155)
# Stacktrace:
# 	GetHandleVerifier [0x0xf6a8a3+63283]
# 	GetHandleVerifier [0x0xf6a8e4+63348]
# 	(No symbol) [0x0xda3e43]
# 	(No symbol) [0x0xda156b]
# 	(No symbol) [0x0xd94d32]
# 	(No symbol) [0x0xd96768]
# 	(No symbol) [0x0xd94fc8]
# 	(No symbol) [0x0xd94b03]
# 	(No symbol) [0x0xd94811]
# 	(No symbol) [0x0xd927b4]
# 	(No symbol) [0x0xd9315b]
# 	(No symbol) [0x0xda785e]
# 	(No symbol) [0x0xe332e7]
# 	(No symbol) [0x0xe1141c]
# 	(No symbol) [0x0xe3271a]
# 	(No symbol) [0x0xe11216]
# 	(No symbol) [0x0xde0855]
# 	(No symbol) [0x0xde16f4]
# 	GetHandleVerifier [0x0x11dbb43+2623955]
# 	GetHandleVerifier [0x0x11d6daa+2604090]
# 	GetHandleVerifier [0x0xf9069a+218410]
# 	GetHandleVerifier [0x0xf80ed8+154984]
# 	GetHandleVerifier [0x0xf8742d+180925]
# 	GetHandleVerifier [0x0xf722b8+94536]
# 	GetHandleVerifier [0x0xf72442+94930]
# 	GetHandleVerifier [0x0xf5d5ea+9338]
# 	BaseThreadInitThunk [0x0x75f05d49+25]
# 	RtlInitializeExceptionChain [0x0x7792d2fb+107]
# 	RtlGetAppContainerNamedObjectPath [0x0
www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Foer.kec.ac.ke%2F&title=Main
# 2025-09-08 08:53:24,267 | INFO     | ✅ Successfully scraped: Grade 4...
# 2025-09-08 08:53:24,271 | INFO     | Scraping: https://lms.kec.ac.ke/mod/page/view.php?id=160
# 2025-09-08 08:53:25,594 | INFO     | ✅ Successfully scraped: General Knowledge...
# 2025-09-08 08:53:26,096 | INFO     | ✅ Successfully scraped: Health Literacy...
# 2025-09-08 08:53:26,839 | INFO     | ✅ Successfully scraped: Sign in...
# 2025-09-08 08:53:26,841 | INFO     | 🎉 Scraping completed! Collected 95 content items
# 2025-09-08 08:53:26,841 | INFO     | ❌ Failed URLs: 0
# 2025-09-08 08:53:26,844 | INFO     | 📊 Quality filtering: 95 → 94 items
# 2025-09-08 08:53:27,039 | INFO     | 💾 Data saved:
# 2025-09-08 08:53:27,041 | INFO     |   - JSON: masters_research_dataset_20250908_085326.json
# 2025-09-08 08:53:27,045 | INFO     |   - CSV: masters_research_dataset_20250908_085326.csv
# 2025-09-08 08:53:27,047 | INFO     |   - Stats: masters_research_dataset_stats_20250908_085326.json
# 2025-09-08 08:53:27,078 | INFO     | ✅ Comprehensive data collection completed successfully
# 2025-09-08 08:53:27,080 | INFO     | 🧠 Phase 2: Advanced NLP Analysis
# 2025-09-08 08:53:30,635 | INFO     | Loading dataset: masters_research_dataset_20250908_085326.csv
# 2025-09-08 08:53:30,719 | INFO     | 📊 Dataset loaded: 95 documents
# 2025-09-08 08:53:30,746 | INFO     | 🔧 Extracting curriculum-specific features...
# 2025-09-08 08:53:30,749 | INFO     | 🔍 Extracting curriculum-specific features...
# 2025-09-08 08:54:15,046 | INFO     | ✅ Processed 94 documents with curriculum features
# 2025-09-08 08:54:15,049 | INFO     | 🎯 Performing LDA topic modeling (30 topics)...
# 2025-09-08 08:54:15,049 | INFO     | 🎯 Performing LDA topic modeling with 30 topics...
# 2025-09-08 08:56:55,363 | INFO     | 💾 LDA model saved as lda_curriculum_model_20250908_085655.pkl
# 2025-09-08 08:56:55,363 | INFO     | ✅ LDA topic modeling completed
# 2025-09-08 08:56:55,367 | INFO     | 📈 Topic coherence score: 0.6268
# 2025-09-08 08:56:55,370 | INFO     | 🌳 Performing hierarchical clustering (25 clusters)...
# 2025-09-08 08:56:55,371 | INFO     | 🌳 Performing hierarchical clustering with 25 clusters...
# 2025-09-08 08:56:56,039 | INFO     | 📊 Clustering metrics:
# 2025-09-08 08:56:56,041 | INFO     |   - Silhouette Score: 0.717
# 2025-09-08 08:56:56,043 | INFO     |   - Calinski-Harabasz Score: 47.575
# 2025-09-08 08:56:56,181 | INFO     | ✅ Hierarchical clustering completed
# 2025-09-08 08:56:56,188 | INFO     | 🗺️ Generating comprehensive curriculum map...
# 2025-09-08 08:56:56,191 | INFO     | 🗺️ Generating curriculum map...
# 2025-09-08 08:56:56,209 | INFO     | ✅ Curriculum map generated
# 2025-09-08 08:56:56,209 | INFO     | 📊 Creating research-grade visualizations...
# 2025-09-08 08:56:56,213 | INFO     | 📊 Creating visualizations...
# 2025-09-08 08:57:02,977 | INFO     | 📊 Visualizations saved as curriculum_analysis_20250908_085658.png
# 2025-09-08 08:57:05,384 | INFO     | 💾 Results saved:
# 2025-09-08 08:57:05,384 | INFO     |   - Data: masters_research_nlp_results_20250908_085705.csv
# 2025-09-08 08:57:05,388 | INFO     |   - Curriculum Map: curriculum_map_20250908_085705.json
# 2025-09-08 08:57:05,391 | INFO     |   - Topics: topic_analysis_20250908_085705.json
# 2025-09-08 08:57:05,392 | INFO     |   - Clusters: cluster_analysis_20250908_085705.json
# 2025-09-08 08:57:05,393 | INFO     | ✅ Advanced NLP analysis completed successfully
# 2025-09-08 08:57:05,393 | INFO     | 🤖 Phase 3: ML Classification
# 2025-09-08 08:57:05,781 | INFO     | 🔧 Preparing ML training data...
# 2025-09-08 08:57:11,056 | INFO     | 🎯 Training classification models...
# RandomForest: 0.853 (+/- 0.155)
# LogisticRegression: 0.853 (+/- 0.053)
# SVM: 0.893 (+/- 0.065)
# GradientBoosting: 0.760 (+/- 0.200)
#
# Best Model Accuracy: 0.789
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      general       0.69      1.00      0.82         9
#    geography       0.00      0.00      0.00         1
#      history       0.00      0.00      0.00         1
#  mathematics       0.00      0.00      0.00         1
#      science       1.00      0.86      0.92         7
#
#     accuracy                           0.79        19
#    macro avg       0.34      0.37      0.35        19
# weighted avg       0.70      0.79      0.73        19
#
# 2025-09-08 08:57:50,000 | INFO     | 💬 Initializing question answering system...
# 2025-09-08 08:57:50,194 | INFO     | ✅ ML classification completed successfully
# 2025-09-08 08:57:50,199 | INFO     | 📋 Phase 4: Research Report Generation
# 2025-09-08 08:57:50,283 | INFO     | ✅ Masters research report generated: masters_research_comprehensive_report_20250908_085750.json
# 2025-09-08 08:57:50,283 | INFO     |
# ================================================================================
# 2025-09-08 08:57:50,283 | INFO     | 🎓 MASTERS RESEARCH PIPELINE SUMMARY
# 2025-09-08 08:57:50,283 | INFO     | ================================================================================
# 2025-09-08 08:57:50,283 | INFO     | 📊 EXECUTION STATISTICS:
# 2025-09-08 08:57:50,288 | INFO     |    Total Execution Time: 0:09:32.503030
# 2025-09-08 08:57:50,288 | INFO     |    Phases Completed: 5
# 2025-09-08 08:57:50,291 | INFO     |    Errors Encountered: 0
# 2025-09-08 08:57:50,291 | INFO     |    Documents Collected: 95
# 2025-09-08 08:57:50,292 | INFO     |    Quality Documents: 94
# 2025-09-08 08:57:50,293 | INFO     |    Topics Discovered: 30
# 2025-09-08 08:57:50,293 | INFO     |    Clusters Formed: 25
# 2025-09-08 08:57:50,293 | INFO     |    Topic Coherence: 0.6268
# 2025-09-08 08:57:50,297 | INFO     |
# 📁 GENERATED FILES:
# 2025-09-08 08:57:50,299 | INFO     |    DATA_COLLECTION: Multiple output files generated
# 2025-09-08 08:57:50,299 | INFO     |    NLP_ANALYSIS: Multiple output files generated
# 2025-09-08 08:57:50,299 | INFO     |
# ✅ RESEARCH OBJECTIVES ACHIEVED:
# 2025-09-08 08:57:50,299 | INFO     |    ✓ Automated curriculum topic clustering implemented
# 2025-09-08 08:57:50,304 | INFO     |    ✓ LDA topic modeling successfully applied
# 2025-09-08 08:57:50,305 | INFO     |    ✓ Hierarchical clustering for content organization
# 2025-09-08 08:57:50,306 | INFO     |    ✓ Curriculum maps automatically generated
# 2025-09-08 08:57:50,306 | INFO     |    ✓ Content gaps and overlaps detected
# 2025-09-08 08:57:50,306 | INFO     |    ✓ Data-driven insights for curriculum design
# 2025-09-08 08:57:50,310 | INFO     | ================================================================================
# 2025-09-08 08:57:50,310 | INFO     | 🎉 MASTERS RESEARCH PIPELINE COMPLETED SUCCESSFULLY!
#
# 🎉 MASTERS RESEARCH COMPLETED SUCCESSFULLY!
# Check the generated files for comprehensive results and analysis.
# 📋 Detailed logs available in: logs\masters_research_execution_20250908_084817.log

# %% [markdown]
# ## Research Results and Analysis
#
# The following cells will display comprehensive results from the curriculum topic clustering analysis, including:
#
# 1. **Data Collection Statistics**
# 2. **Topic Modeling Results (LDA)**
# 3. **Hierarchical Clustering Analysis**
# 4. **Curriculum Mapping Insights**
# 5. **Content Gap Analysis**
# 6. **Research Visualizations**

# %%
# RESULTS VISUALIZATION AND ANALYSIS - UPDATED CELL 3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Configure matplotlib for Jupyter
# %matplotlib inline
plt.rcParams['figure.figsize'] = (14, 10)
plt.rcParams['font.size'] = 10

try:
    # Load latest results with better error handling
    result_files = list(Path('.').glob('masters_research_*.json'))
    
    # Filter out dataset and stats files, prioritize comprehensive reports
    filtered_files = []
    comprehensive_files = []
    
    for f in result_files:
        if 'dataset' not in f.name and 'stats' not in f.name:
            if 'comprehensive_report' in f.name:
                comprehensive_files.append(f)
            else:
                filtered_files.append(f)
    
    # Use comprehensive report if available, otherwise use other files
    target_files = comprehensive_files if comprehensive_files else filtered_files
    
    if target_files:
        latest_results = max(target_files, key=lambda x: x.stat().st_mtime)
        
        print(f"📊 RESEARCH RESULTS SUMMARY")
        print(f"Report: {latest_results.name}")
        
        # Load with UTF-8 encoding
        with open(latest_results, 'r', encoding='utf-8') as f:
            research_data = json.load(f)
        
        # Extract metadata
        metadata = research_data.get('research_metadata', {})
        print(f"Execution Time: {metadata.get('execution_duration', 'N/A')}")
        print(f"Phases Completed: {metadata.get('total_phases_completed', 0)}/4")
        print(f"Errors Encountered: {metadata.get('errors_encountered', 0)}")
        
        # Extract methodology data
        methodology = research_data.get('methodology', {})
        data_collection = methodology.get('data_collection', {})
        eval_metrics = methodology.get('evaluation_metrics', {})
        nlp_techniques = methodology.get('nlp_techniques', {})
        
        print(f"\n📈 KEY PERFORMANCE METRICS:")
        print(f"Documents Processed: {data_collection.get('total_documents', 0):,}")
        print(f"Topic Coherence Score: {eval_metrics.get('topic_coherence', 0):.4f}")
        print(f"Topic Modeling: {nlp_techniques.get('topic_modeling', 'N/A')}")
        print(f"Clustering Method: {nlp_techniques.get('clustering', 'N/A')}")
        
        # Extract results data
        results = research_data.get('results', {})
        if results:
            data_results = results.get('data_collection_results', {})
            print(f"Items Scraped: {data_results.get('total_items_scraped', 0):,}")
            print(f"Quality Items Retained: {data_results.get('quality_items_retained', 0):,}")
            print(f"Collection Status: {data_results.get('status', 'N/A')}")
        
        # Research objectives status
        objectives = research_data.get('research_objectives', {})
        if objectives:
            achieved = objectives.get('achieved', False)
            status_icon = "✅" if achieved else "❌"
            print(f"\n🎯 RESEARCH OBJECTIVES: {status_icon} {'ACHIEVED' if achieved else 'PENDING'}")
            print(f"Primary: {objectives.get('primary', 'N/A')}")
        
        # Create visualization
        print(f"\n📊 Creating Research Visualization...")
        
        # Set up the plots
        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
        fig.suptitle('Masters Research: Curriculum Topic Clustering Results', 
                    fontsize=16, fontweight='bold', y=0.98)
        
        # Plot 1: Data Collection Results
        scraped = data_results.get('total_items_scraped', 0) if results else 0
        retained = data_results.get('quality_items_retained', 0) if results else 0
        
        categories = ['Items\nScraped', 'Quality\nRetained']
        values = [scraped, retained]
        colors = ['#3498db', '#2ecc71']
        
        bars1 = ax1.bar(categories, values, color=colors, alpha=0.8, edgecolor='white', linewidth=2)
        ax1.set_title('Data Collection Results', fontweight='bold', pad=20)
        ax1.set_ylabel('Number of Documents')
        ax1.grid(axis='y', alpha=0.3)
        
        # Add value labels
        for bar, value in zip(bars1, values):
            height = bar.get_height()
            ax1.text(bar.get_x() + bar.get_width()/2., height + max(values)*0.01,
                    f'{value}', ha='center', va='bottom', fontweight='bold', fontsize=12)
        
        # Plot 2: Topic Coherence Score
        coherence = eval_metrics.get('topic_coherence', 0)
        coherence_data = [coherence, 1.0 - coherence]
        labels = [f'Coherence\n{coherence:.3f}', f'Remaining\n{1-coherence:.3f}']
        colors2 = ['#e74c3c', '#ecf0f1']
        
        wedges, texts, autotexts = ax2.pie(coherence_data, labels=labels, colors=colors2, 
                                          autopct='%1.1f%%', startangle=90, 
                                          textprops={'fontweight': 'bold'})
        ax2.set_title(f'Topic Coherence Analysis', fontweight='bold', pad=20)
        
        # Plot 3: NLP Configuration
        # Extract numbers from strings
        topics_str = nlp_techniques.get('topic_modeling', 'LDA with 30 topics')
        clusters_str = nlp_techniques.get('clustering', 'Hierarchical clustering with 25 clusters')
        
        topics = 30  # default
        clusters = 25  # default
        
        # Try to extract actual numbers
        try:
            import re
            topic_match = re.search(r'(\d+)\s*topics?', topics_str, re.IGNORECASE)
            if topic_match:
                topics = int(topic_match.group(1))
            
            cluster_match = re.search(r'(\d+)\s*clusters?', clusters_str, re.IGNORECASE)
            if cluster_match:
                clusters = int(cluster_match.group(1))
        except:
            pass
        
        config_labels = ['LDA\nTopics', 'Hierarchical\nClusters']
        config_values = [topics, clusters]
        colors3 = ['#9b59b6', '#f39c12']
        
        bars3 = ax3.bar(config_labels, config_values, color=colors3, alpha=0.8, 
                       edgecolor='white', linewidth=2)
        ax3.set_title('NLP Analysis Configuration', fontweight='bold', pad=20)
        ax3.set_ylabel('Count')
        ax3.grid(axis='y', alpha=0.3)
        
        # Add value labels
        for bar, value in zip(bars3, config_values):
            height = bar.get_height()
            ax3.text(bar.get_x() + bar.get_width()/2., height + max(config_values)*0.01,
                    f'{value}', ha='center', va='bottom', fontweight='bold', fontsize=12)
        
        # Plot 4: Execution Summary
        phases = metadata.get('total_phases_completed', 0)
        errors = metadata.get('errors_encountered', 0)
        max_phases = 4
        
        summary_labels = [f'Phases\nCompleted', f'Errors\nEncountered']
        summary_values = [phases, errors]
        colors4 = ['#2ecc71', '#e74c3c']
        
        bars4 = ax4.bar(summary_labels, summary_values, color=colors4, alpha=0.8,
                       edgecolor='white', linewidth=2)
        ax4.set_title(f'Pipeline Execution Summary\nDuration: {metadata.get("execution_duration", "N/A")}', 
                     fontweight='bold', pad=20)
        ax4.set_ylabel('Count')
        ax4.set_ylim(0, max(max_phases + 1, max(summary_values) + 1))
        ax4.grid(axis='y', alpha=0.3)
        
        # Add value labels
        for bar, value in zip(bars4, summary_values):
            height = bar.get_height()
            ax4.text(bar.get_x() + bar.get_width()/2., height + 0.1,
                    f'{value}', ha='center', va='bottom', fontweight='bold', fontsize=12)
        
        # Add phase completion indicator
        ax4.text(0, phases + 0.3, f'{phases}/{max_phases}', ha='center', va='bottom', 
                fontweight='bold', fontsize=10, color='darkgreen')
        
        plt.tight_layout()
        plt.subplots_adjust(top=0.93)
        plt.show()
        
        # Final summary
        print(f"\n🎉 PIPELINE STATUS: {'✅ SUCCESS' if phases == 4 and errors == 0 else '⚠️ PARTIAL'}")
        print(f"📁 Results saved in: {latest_results.name}")
        print(f"🚀 Ready for thesis writing and academic presentation!")
        
    else:
        print("⚠️ No valid results files found.")
        print("Available JSON files:")
        all_json = list(Path('.').glob('*.json'))
        for f in all_json[:5]:
            print(f"   - {f.name}")
        print("\nRun the main pipeline first: python main.py")

except FileNotFoundError as e:
    print(f"❌ File not found: {e}")
    print("Make sure you're in the correct directory with the results files.")
    
except json.JSONDecodeError as e:
    print(f"❌ JSON parsing error: {e}")
    print("The results file may be corrupted. Try running the pipeline again.")
    
except Exception as e:
    print(f"❌ Unexpected error: {e}")
    print(f"Error type: {type(e).__name__}")
    print("Check that all required packages are installed and try again.")
# Out:
# 📊 RESEARCH RESULTS SUMMARY
# Report: masters_research_comprehensive_report_20250908_085750.json
# Execution Time: 0:09:32.418482
# Phases Completed: 4/4
# Errors Encountered: 0
#
# 📈 KEY PERFORMANCE METRICS:
# Documents Processed: 94
# Topic Coherence Score: 0.6268
# Topic Modeling: LDA with 30 topics
# Clustering Method: Hierarchical clustering with 25 clusters
# Items Scraped: 95
# Quality Items Retained: 94
# Collection Status: SUCCESS
#
# 🎯 RESEARCH OBJECTIVES: ✅ ACHIEVED
# Primary: Develop NLP-based system for curriculum topic clustering from educational textbooks
#
# 📊 Creating Research Visualization...
# 🎉 PIPELINE STATUS: ✅ SUCCESS
# 📁 Results saved in: masters_research_comprehensive_report_20250908_085750.json
# 🚀 Ready for thesis writing and academic presentation!
